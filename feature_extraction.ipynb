# %%
import json
import string
from feature_extractor import FeatureExtractor

# %%
with open("data/res_skill_dictionary") as reader:
    res_skill_dictionary = json.loads(reader.readline())

# %%
with open("data/not_null_resumes") as reader:
    not_null_resumes = json.loads(reader.readline())

# %%
extractor = FeatureExtractor(res_skill_dictionary)

# %%
extractor.extract_features("""skype: alexander.sulhochev
I work as data scientist in Tesal motors. I also work with spring and java in microsoft.
Particulary I know spring framework, react.js, spring security and .net mvc framework.
My skills:
java
c/c++
python
mysql
postgresql .net c# лиюблю заниматься машинным обучением""")
# Out:
# [('.NETFramework', 179),
#  ('.NETFramework', 244),
#  ('C++', 216),
#  ('C#', 249),
#  ('C', 214),
#  ('datascience', 36),
#  ('JavaPlatformStandardEdition', 96),
#  ('JavaPlatformStandardEdition', 209),
#  ('JavaScript', 156),
#  ('mvc', 184),
#  ('machinelearning', 270),
#  ('MySQL', 227),
#  ('Python', 220),
#  ('PostgreSQL', 233),
#  ('ReactJS', 150),
#  ('SpringFramework', 133),
#  ('SpringFramework', 85),
#  ('SpringSecurity', 159)]

# %%
developers = {}
print(len(not_null_resumes.keys()))
i = 0
for k in not_null_resumes.keys():
    if i % 100 == 0:
         print(i)
    i += 1
    features = extractor.extract_features(not_null_resumes[k])
    if features != []:
        developers[k] = features
# Out:
# 3609
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600

# %%
len(developers.keys())
# Out:
# 3583

# %%
with open("data/developers", "w") as writer:
    writer.write(json.dumps(developers))

# %%
list(developers.values())[:10]
# Out:
# [[('ApacheStruts', 384),
#   ('ApacheStruts', 1377),
#   ('ApacheTomcat', 683),
#   ('ApacheTomcat', 1424),
#   ('BorlandC++', 492),
#   ('CascadingStyleSheets', 334),
#   ('CascadingStyleSheets', 659),
#   ('Delphi', 485),
#   ('Delphi', 894),
#   ('FreeBSD', 279),
#   ('HardDriveInspector', 1666),
#   ('IntelliJIDEA', 461),
#   ('IntelliJIDEA', 1410),
#   ('IntelliJIDEA', 470),
#   ('IntelliJIDEA', 1419),
#   ('JavaPlatformStandardEdition', 360),
#   ('JavaScript', 338),
#   ('JavaDatabaseConnectivity', 391),
#   ('JavaDatabaseConnectivity', 1384),
#   ('JDOM', 440),
#   ('MicrosoftVisualStudio', 508),
#   ('MicrosoftVisualStudio', 901),
#   ('MySQL', 423),
#   ('NativeClient', 1573),
#   ('OracleSQLDeveloper', 416),
#   ('OracleSQLDeveloper', 676),
#   ('OracleSQLDeveloper', 887),
#   ('OracleSQLDeveloper', 1403),
#   ('PostgreSQL', 429),
#   ('PostgreSQL', 704),
#   ('statistics', 1245),
#   ('xpath', 451)],
#  [('1С', 1231),
#   ('ASPLinux', 854),
#   ('Delphi', 155),
# ...
